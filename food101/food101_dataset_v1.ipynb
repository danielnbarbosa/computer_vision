# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
bs = 64

# %%
path = Path('/home/ubuntu/food-101')
path
# Out:
# PosixPath('/home/ubuntu/food-101')

# %%
data = ImageDataBunch.from_csv(path, folder='images', csv_labels='train.csv', fn_col=0, label_col=1, 
                               suffix='.jpg', size=224, bs=bs, ds_tfms=get_transforms(), test='test')

# %%
print(len(data.train_ds))
print(len(data.valid_ds))
print(len(data.test_ds))
# Out:
# 60600

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['apple_pie', 'baby_back_ribs', 'baklava', 'beef_carpaccio', 'beef_tartare', 'beet_salad', 'beignets', 'bibimbap', 'bread_pudding', 'breakfast_burrito', 'bruschetta', 'caesar_salad', 'cannoli', 'caprese_salad', 'carrot_cake', 'ceviche', 'cheese_plate', 'cheesecake', 'chicken_curry', 'chicken_quesadilla', 'chicken_wings', 'chocolate_cake', 'chocolate_mousse', 'churros', 'clam_chowder', 'club_sandwich', 'crab_cakes', 'creme_brulee', 'croque_madame', 'cup_cakes', 'deviled_eggs', 'donuts', 'dumplings', 'edamame', 'eggs_benedict', 'escargots', 'falafel', 'filet_mignon', 'fish_and_chips', 'foie_gras', 'french_fries', 'french_onion_soup', 'french_toast', 'fried_calamari', 'fried_rice', 'frozen_yogurt', 'garlic_bread', 'gnocchi', 'greek_salad', 'grilled_cheese_sandwich', 'grilled_salmon', 'guacamole', 'gyoza', 'hamburger', 'hot_and_sour_soup', 'hot_dog', 'huevos_rancheros', 'hummus', 'ice_cream', 'lasagna', 'lobster_bisque', 'lobster_roll_sandwich', 'macaroni_and_cheese', 'macarons', 'miso_s
# ...

# %%
learn = create_cnn(data, models.resnet34, metrics=accuracy)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /home/ubuntu/.torch/models/resnet34-333f7ec4.pth
# 100%|██████████| 87306240/87306240 [00:00<00:00, 112860582.03it/s]

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 44:56 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>2.214398</th>
#     <th>1.807610</th>
#     <th>0.461219</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.899746</th>
#     <th>1.522950</th>
#     <th>0.392171</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>1.657138</th>
#     <th>1.370545</th>
#     <th>0.354875</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>1.541147</th>
#     <th>1.341189</th>
#     <th>0.347284</th>
#   </tr>
# </table>

# %%
learn.save(' v1_stage1')

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.most_confused(min_val=10)
# Out:
# [('chocolate_mousse', 'chocolate_cake', 22),
#  ('cheesecake', 'panna_cotta', 20),
#  ('pulled_pork_sandwich', 'hamburger', 19),
#  ('tuna_tartare', 'beef_tartare', 19),
#  ('chocolate_cake', 'chocolate_mousse', 15),
#  ('chocolate_mousse', 'panna_cotta', 15),
#  ('filet_mignon', 'steak', 15),
#  ('paella', 'fried_rice', 15),
#  ('apple_pie', 'bread_pudding', 14),
#  ('donuts', 'beignets', 14),
#  ('filet_mignon', 'pork_chop', 14),
#  ('grilled_salmon', 'pork_chop', 14),
#  ('pork_chop', 'filet_mignon', 14),
#  ('steak', 'filet_mignon', 14),
#  ('dumplings', 'gyoza', 13),
#  ('steak', 'baby_back_ribs', 13),
#  ('steak', 'pork_chop', 13),
#  ('steak', 'prime_rib', 13),
#  ('beef_tartare', 'tuna_tartare', 12),
#  ('clam_chowder', 'lobster_bisque', 12),
#  ('foie_gras', 'pork_chop', 12),
#  ('lobster_bisque', 'clam_chowder', 12),
#  ('cheesecake', 'strawberry_shortcake', 11),
#  ('chocolate_cake', 'red_velvet_cake', 11),
#  ('french_fries', 'poutine', 11),
#  ('ramen', 'pho', 11)]

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-4))
# Out:
# Total time: 23:52 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.448194</th>
#     <th>1.252006</th>
#     <th>0.327018</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.368747</th>
#     <th>1.214014</th>
#     <th>0.317183</th>
#   </tr>
# </table>

# %%
learn.save('v1_stage2')
